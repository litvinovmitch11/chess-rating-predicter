# %%
from preprocessor import Preprocessor

proc = Preprocessor()

# %%
proc.read_pgn_from_string("1. e4 e5 2. Bc4 d6 3. Qh5 Nf6 4. Qxf7#")
proc.calculate_wdl()
proc.calculate_evaluation_stat()
proc.calculate_n_best_lines(n=5)

# %%
proc.get_stats_per_move(add_wdl_stats=True, add_evaluation_stats=True, n_best_lines=3)
# Out:
#    move    win   draw   lose  centipawns  moves_to_force_mate  \
# 0  e2e4  0.020  0.900  0.080        33.0                  NaN
# 1  e7e5  0.088  0.894  0.018        38.0                  NaN
# 2  f1c4  0.047  0.918  0.035        -7.0                  NaN
# 3  d7d6  0.087  0.895  0.018        37.0                  NaN
# 4  d1h5  0.080  0.901  0.019       -34.0                  NaN
# 5  g8f6  1.000  0.000  0.000         NaN                  1.0
# 6  h5f7    NaN    NaN    NaN         NaN                  0.0
#
#   best_line_1_move  best_line_1_centipawns  best_line_1_moves_to_force_mate  \
# 0             e2e4                    49.0                              NaN
# 1             c7c5                    37.0                              NaN
# 2             g1f3                    49.0                              NaN
# 3             g8f6                     5.0                              NaN
# 4             g1f3                    39.0                              NaN
# 5             g7g6                   -32.0                              NaN
# 6             h5f7                     NaN                              1.0
#
#   best_line_2_move  best_line_2_centipawns best_line_2_moves_to_force_mate  \
# 0             g1f3                      43                            None
# 1             e7e6                      43                            None
# 2             f1c4                      14                            None
# 3             b8c6                      27                            None
# 4             b1c3                      32                            None
# 5             d8e7                       8                            None
# 6             h5e2                     -46                            None
#
#   best_line_3_move  best_line_3_centipawns best_line_3_moves_to_force_mate
# 0             d2d4                      37                            None
# 1             e7e5                      43                            None
# 2             b1c3                      10                            None
# 3             f8c5                      32                            None
# 4             d2d4                      31                            None
# 5             d8d7                      36                            None
# 6             h5f3                     -69                            None

# %%
import chess.pgn

with open("../data/lichess_db_standard_rated_2013-01.pgn") as pgn:
    game = chess.pgn.read_game(pgn)
    moves = str(game.mainline_moves())
    
proc.read_pgn_from_string(moves)
proc.calculate_wdl()
proc.calculate_evaluation_stat()

# %%
proc.get_stats_per_move(add_wdl_stats=True, add_evaluation_stats=True)
# Out:
#     move    win   draw   lose  centipawns  moves_to_force_mate
# 0   e2e4  0.020  0.900  0.080        33.0                  NaN
# 1   e7e6  0.093  0.890  0.017        41.0                  NaN
# 2   d2d4  0.014  0.878  0.108        49.0                  NaN
# 3   b7b6  0.275  0.721  0.004       101.0                  NaN
# 4   a2a3  0.008  0.826  0.166        71.0                  NaN
# 5   c8b7  0.254  0.741  0.005        95.0                  NaN
# 6   b1c3  0.004  0.706  0.290       103.0                  NaN
# 7   g8h6  0.821  0.179  0.000       209.0                  NaN
# 8   c1h6  0.001  0.331  0.668       172.0                  NaN
# 9   g7h6  0.748  0.251  0.001       187.0                  NaN
# 10  f1e2  0.004  0.722  0.274        98.0                  NaN
# 11  d8g5  0.496  0.503  0.001       138.0                  NaN
# 12  e2g4  0.011  0.881  0.108        49.0                  NaN
# 13  h6h5  0.155  0.838  0.007        66.0                  NaN
# 14  g1f3  1.000  0.000  0.000      -712.0                  NaN
# 15  g5g6  0.376  0.622  0.002       115.0                  NaN
# 16  f3h4  1.000  0.000  0.000      -806.0                  NaN
# 17  g6g5  0.000  0.000  1.000      -457.0                  NaN
# 18  g4h5  0.999  0.001  0.000      -435.0                  NaN
# 19  g5h4  0.000  0.001  0.999      -434.0                  NaN
# 20  d1f3  1.000  0.000  0.000      -446.0                  NaN
# 21  e8d8  0.000  0.009  0.991      -317.0                  NaN
# 22  f3f7  0.991  0.009  0.000      -315.0                  NaN
# 23  b8c6  1.000  0.000  0.000         NaN                  1.0
# 24  f7e8    NaN    NaN    NaN         NaN                  0.0
